# %%
# %pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: numpy>=1.19.5 in /home/dorsafdhouibi/miniconda3/envs/kedro-environment/lib/python3.12/site-packages (from scikit-learn) (2.2.4)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.15.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.6.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 31.0 MB/s eta 0:00:00 MB/s eta 0:00:0101
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading scipy-1.15.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 30.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.6.1 scipy-1.15.2 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext kedro.ipython
# Out:
# [04/16/25 09:14:01] INFO     Using                                                                  ]8;id=465218;file:///home/dorsafdhouibi/miniconda3/envs/kedro-environment/lib/python3.12/site-packages/kedro/framework/project/__init__.py\__init__.py]8;;\:]8;id=184922;file:///home/dorsafdhouibi/miniconda3/envs/kedro-environment/lib/python3.12/site-packages/kedro/framework/project/__init__.py#270\270]8;;\
#                              '/home/dorsafdhouibi/miniconda3/envs/kedro-environment/lib/python3.12/
#                              site-packages/kedro/framework/project/rich_logging.yml' as logging
#                              configuration.
#                     INFO     Registered line magic '%reload_kedro'                                   ]8;id=100416;file:///home/dorsafdhouibi/miniconda3/envs/kedro-environment/lib/python3.12/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=16169;file:///home/dorsafdhouibi/miniconda3/envs/kedro-environment/lib/python3.12/site-packages/kedro/ipython/__init__.py#63\63]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=45281;file:///home/dorsafdhouibi/miniconda3/envs/kedro-environment/lib/python3.12/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=674018;file:///home/dorsafdhouibi/miniconda3/envs/kedro-environment/lib/python3.12/site-packages/kedro/ipython/__init__.py#65\65]8;;\
#                     INFO     Resolved project path as:                                              ]8;id=369072;file:///home/dorsafdhouibi/miniconda3/envs/kedro-environment/lib/python3.12/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=817573;file:///home/dorsafdhouibi/miniconda3/envs/kedro-environment/lib/python3.12/site-packages/kedro/ipython/__init__.py#180\180]8;;\
#                              /home/dorsafdhouibi/Documents/bi_project/spaceflights.
#                              To set a different path, run '%reload_kedro <project_root>'
#                     WARNING  /home/dorsafdhouibi/miniconda3/envs/kedro-environment/lib/python3.12/s ]8;id=260755;file:///home/dorsafdhouibi/miniconda3/envs/kedro-environment/lib/python3.12/warnings.py\warnings.py]8;;\:]8;id=901608;file:///home/dorsafdhouibi/miniconda3/envs/kedro-environment/lib/python3.12/warnings.py#112\112]8;;\
#                              ite-packages/kedro/io/data_catalog.py:165: KedroDeprecationWarning:
#                              `DataCatalog` has been deprecated and will be replaced by
#                              `KedroDataCatalog`, in Kedro 1.0.0.Currently some `KedroDataCatalog`
#                              APIs have been retained for compatibility with `DataCatalog`,
#                              including the `datasets` property and the `get_datasets`,
#                              `_get_datasets`, `add`,` list`, `add_feed_dict`, and `shallow_copy`
#                              methods. These will be removed or replaced with updated alternatives
#                              in Kedro 1.0.0. For more details, refer to the documentation:
#                              https://docs.kedro.org/en/stable/data/index.html#kedrodatacatalog-expe
#                              rimental-feature
#                                warnings.warn(
# [04/16/25 09:14:01] WARNING  /home/dorsafdhouibi/miniconda3/envs/kedro-environment/lib/python3.12/s ]8;id=498500;file:///home/dorsafdhouibi/miniconda3/envs/kedro-environment/lib/python3.12/warnings.py\warnings.py]8;;\:]8;id=276027;file:///home/dorsafdhouibi/miniconda3/envs/kedro-environment/lib/python3.12/warnings.py#112\112]8;;\
#                              ite-packages/kedro/io/data_catalog.py:165: KedroDeprecationWarning:
#                              `DataCatalog` has been deprecated and will be replaced by
#                              `KedroDataCatalog`, in Kedro 1.0.0.Currently some `KedroDataCatalog`
#                              APIs have been retained for compatibility with `DataCatalog`,
#                              including the `datasets` property and the `get_datasets`,
#                              `_get_datasets`, `add`,` list`, `add_feed_dict`, and `shallow_copy`
#                              methods. These will be removed or replaced with updated alternatives
#                              in Kedro 1.0.0. For more details, refer to the documentation:
#                              https://docs.kedro.org/en/stable/data/index.html#kedrodatacatalog-expe
#                              rimental-feature
#                                warnings.warn(
#                     INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=138218;file:///home/dorsafdhouibi/miniconda3/envs/kedro-environment/lib/python3.12/site-packages/kedro_telemetry/plugin.py\plugin.py]8;;\:]8;id=562413;file:///home/dorsafdhouibi/miniconda3/envs/kedro-environment/lib/python3.12/site-packages/kedro_telemetry/plugin.py#233\233]8;;\
#                              the product. No personal data or IP addresses are stored on our side. If
#                              you want to opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK`
#                              environment variables, or create a `.telemetry` file in the current
#                              working directory with the contents `consent: false`. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
# [04/16/25 09:14:02] INFO     Kedro project spaceflights                                             ]8;id=136241;file:///home/dorsafdhouibi/miniconda3/envs/kedro-environment/lib/python3.12/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=553116;file:///home/dorsafdhouibi/miniconda3/envs/kedro-environment/lib/python3.12/site-packages/kedro/ipython/__init__.py#146\146]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=228158;file:///home/dorsafdhouibi/miniconda3/envs/kedro-environment/lib/python3.12/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=397490;file:///home/dorsafdhouibi/miniconda3/envs/kedro-environment/lib/python3.12/site-packages/kedro/ipython/__init__.py#147\147]8;;\
#                              'pipelines'
#                     INFO     Registered line magic 'run_viz'                                        ]8;id=58633;file:///home/dorsafdhouibi/miniconda3/envs/kedro-environment/lib/python3.12/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=397594;file:///home/dorsafdhouibi/miniconda3/envs/kedro-environment/lib/python3.12/site-packages/kedro/ipython/__init__.py#153\153]8;;\

# %%
df= catalog.load("model_input_table")
df.head()
# Out:
# [04/16/25 09:14:37] INFO     Loading data from model_input_table (ParquetDataset)...            ]8;id=770888;file:///home/dorsafdhouibi/miniconda3/envs/kedro-environment/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=969889;file:///home/dorsafdhouibi/miniconda3/envs/kedro-environment/lib/python3.12/site-packages/kedro/io/data_catalog.py#401\401]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#     id_x shuttle_location shuttle_type engine_type       engine_vendor  \
# 0  63561             Niue      Type V5     Quantum  ThetaBase Services
# 1  63561             Niue      Type V5     Quantum  ThetaBase Services
# 2  63561             Niue      Type V5     Quantum  ThetaBase Services
# 3  63561             Niue      Type V5     Quantum  ThetaBase Services
# 4  36260         Anguilla      Type V5     Quantum  ThetaBase Services
#
#    engines  passenger_capacity cancellation_policy  crew d_check_complete  \
# 0      1.0                   2              strict   1.0                f
# 1      1.0                   2              strict   1.0                f
# 2      1.0                   2              strict   1.0                f
# 3      1.0                   2              strict   1.0                f
# 4      1.0                   2              strict   1.0                t
#
#    ...  review_scores_crew  review_scores_location  review_scores_price  \
# 0  ...                10.0                     9.0                 10.0
# 1  ...                10.0                     9.0                 10.0
# 2  ...                10.0                     9.0                 10.0
# 3  ...                10.0                     9.0                 10.0
# 4  ...                 9.0                     9.0                  9.0
#
#    number_of_reviews  reviews_per_month   id_y  company_rating  \
# 0                133               1.65  35029            1.00
# 1                133               1.65  35029            1.00
# 2                133               1.65  35029            1.00
# 3                133               1.65  35029            1.00
# 4                  3               0.09  30292            0.67
#
#    company_location  total_fleet_count  iata_approved
# 0              Niue                4.0          False
# 1              Niue                4.0          False
# 2              Niue                4.0          False
# 3              Niue                4.0          False
# 4          Anguilla                6.0          False
#
# [5 rows x 28 columns]

# %%
import sklearn
sklearn.__version__
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# '1.6.1'

# %%
from sklearn.model_selection import train_test_split

# %%
features = [
    "engines",
    "passenger_capacity",
    "crew",
    "d_check_complete",
    "moon_clearance_complete",
    "iata_approved",
    "company_rating",
    "review_scores_rating",
]

# %%
X = df[features]
Y = df["price"]

# %%
X.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#    engines  passenger_capacity  crew d_check_complete  \
# 0      1.0                   2   1.0                f
# 1      1.0                   2   1.0                f
# 2      1.0                   2   1.0                f
# 3      1.0                   2   1.0                f
# 4      1.0                   2   1.0                t
#
#    moon_clearance_complete  iata_approved  company_rating  \
# 0                    False          False            1.00
# 1                    False          False            1.00
# 2                    False          False            1.00
# 3                    False          False            1.00
# 4                    False          False            0.67
#
#    review_scores_rating
# 0                  97.0
# 1                  97.0
# 2                  97.0
# 3                  97.0
# 4                  90.0

# %%
Y.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 0    1325.0
# 1    1325.0
# 2    1325.0
# 3    1325.0
# 4    1780.0
# Name: price, dtype: float64

# %%
shuttles = catalog.load('shuttles')
# Out:
# [04/16/25 10:45:42] INFO     Loading data from shuttles (ExcelDataset)...                       ]8;id=620153;file:///home/dorsafdhouibi/miniconda3/envs/kedro-environment/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=157778;file:///home/dorsafdhouibi/miniconda3/envs/kedro-environment/lib/python3.12/site-packages/kedro/io/data_catalog.py#401\401]8;;\

# %%
import pandas as pd
def _is_true(x: pd.Series) -> pd.Series:
    return x == "t"
shuttles["d_check_complete"] = _is_true(shuttles["d_check_complete"])
shuttles["moon_clearance_complete"] = _is_true(shuttles["moon_clearance_complete"])
shuttles.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       id       shuttle_location shuttle_type engine_type       engine_vendor  \
# 0  63561                   Niue      Type V5     Quantum  ThetaBase Services
# 1  36260               Anguilla      Type V5     Quantum  ThetaBase Services
# 2  57015     Russian Federation      Type V5     Quantum  ThetaBase Services
# 3  14035               Barbados      Type V5      Plasma  ThetaBase Services
# 4  10036  Sao Tome and Principe      Type V2      Plasma  ThetaBase Services
#
#    engines  passenger_capacity cancellation_policy  crew  d_check_complete  \
# 0      1.0                   2              strict   1.0             False
# 1      1.0                   2              strict   1.0             False
# 2      1.0                   2            moderate   0.0             False
# 3      3.0                   6              strict   3.0             False
# 4      2.0                   4              strict   2.0             False
#
#    moon_clearance_complete     price  company_id
# 0                    False  $1,325.0       35029
# 1                    False  $1,780.0       30292
# 2                    False  $1,715.0       19032
# 3                    False  $4,770.0        8238
# 4                    False  $2,820.0       30342

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2)

# %%
len(X_train), len(X_test)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# (607687, 151922)

# %%
len(Y_train), len(Y_test)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# (607687, 151922)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
X_train.dtypes
X_train['d_check_complete'] = _is_true(X_train["d_check_complete"])
X_train.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#          engines  passenger_capacity  crew  d_check_complete  \
# 70573        2.0                   4   2.0              True
# 337841       5.0                  10   5.0              True
# 1598071      3.0                   5   4.0              True
# 174071       2.0                   4   2.0              True
# 1059868      1.0                   2   1.0              True
#
#          moon_clearance_complete  iata_approved  company_rating  \
# 70573                      False          False             1.0
# 337841                     False          False             1.0
# 1598071                    False          False             1.0
# 174071                     False          False             1.0
# 1059868                    False          False             1.0
#
#          review_scores_rating
# 70573                    90.0
# 337841                   90.0
# 1598071                  80.0
# 174071                   80.0
# 1059868                  90.0

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
X_test['d_check_complete'] = _is_true(X_test["d_check_complete"])
X_test.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#          engines  passenger_capacity  crew  d_check_complete  \
# 1155039      1.0                   2   1.0             False
# 1712677      1.0                   2   1.0              True
# 967051       2.0                   4   2.0              True
# 623426       1.0                   3   1.0             False
# 745478       3.0                  10   4.0              True
#
#          moon_clearance_complete  iata_approved  company_rating  \
# 1155039                    False          False            0.97
# 1712677                    False          False            1.00
# 967051                     False          False            1.00
# 623426                     False           True            0.93
# 745478                     False          False            1.00
#
#          review_scores_rating
# 1155039                 100.0
# 1712677                  93.0
# 967051                  100.0
# 623426                   85.0
# 745478                  100.0

# %%
model.predict(X_test)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# array([2371.40190551, 2420.25996267, 3447.21386058, ..., 2410.33857487,
#        3373.35845149, 2431.74235739], shape=(151922,))

# %%
from sklearn.metrics import r2_score

# %%
y_pred = model.predict(X_test)

# %%
Y_test.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 1155039    2183.0
# 1712677    3262.0
# 967051     3067.0
# 623426     2157.0
# 745478     4523.0
# Name: price, dtype: float64

# %%
r2_score(Y_test, y_pred )
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 0.462356221653615
